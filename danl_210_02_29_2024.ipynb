# %% [markdown]
# <a href="https://colab.research.google.com/github/jca100/danl-210-notes/blob/main/danl_210_02_29_2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
# Below is for an interactive display of DataFrame in Colab
from google.colab import data_table
data_table.enable_dataframe_formatter()

nba = pd.read_csv("https://bcdanl.github.io/data/nba.csv")

# %%
nba
# Out:
#                Name                 Team Position  Birthday      Salary
# 0      Shake Milton   Philadelphia 76ers       SG   9/26/96   1445697.0
# 1    Christian Wood      Detroit Pistons       PF   9/27/95   1645357.0
# 2     PJ Washington    Charlotte Hornets       PF   8/23/98   3831840.0
# 3      Derrick Rose      Detroit Pistons       PG   10/4/88   7317074.0
# 4     Marial Shayok   Philadelphia 76ers        G   7/26/95         NaN
# ..              ...                  ...      ...       ...         ...
# 445   Austin Rivers      Houston Rockets       PG    8/1/92   2174310.0
# 446     Harry Giles     Sacramento Kings       PF   4/22/98   2578800.0
# 447     Robin Lopez      Milwaukee Bucks        C    4/1/88   4767000.0
# 448   Collin Sexton  Cleveland Cavaliers       PG    1/4/99   4764960.0
# 449     Ricky Rubio         Phoenix Suns       PG  10/21/90  16200000.0
#
# [450 rows x 5 columns]

# %%
nba = nba.set_index("Name")

# %%
nba
# Out:
#                                Team Position  Birthday      Salary
# Name
# Shake Milton     Philadelphia 76ers       SG   9/26/96   1445697.0
# Christian Wood      Detroit Pistons       PF   9/27/95   1645357.0
# PJ Washington     Charlotte Hornets       PF   8/23/98   3831840.0
# Derrick Rose        Detroit Pistons       PG   10/4/88   7317074.0
# Marial Shayok    Philadelphia 76ers        G   7/26/95         NaN
# ...                             ...      ...       ...         ...
# Austin Rivers       Houston Rockets       PG    8/1/92   2174310.0
# Harry Giles        Sacramento Kings       PF   4/22/98   2578800.0
# Robin Lopez         Milwaukee Bucks        C    4/1/88   4767000.0
# Collin Sexton   Cleveland Cavaliers       PG    1/4/99   4764960.0
# Ricky Rubio            Phoenix Suns       PG  10/21/90  16200000.0
#
# [450 rows x 4 columns]

# %%
nba.loc[ "LeBron James" ]
# Out:
# Team        Los Angeles Lakers
# Position                    PF
# Birthday              12/30/84
# Salary              37436858.0
# Name: LeBron James, dtype: object

# %%
nba.loc[ ["Kawhi Leonard", "Paul George"] ]
# Out:
#                                Team Position Birthday      Salary
# Name
# Kawhi Leonard  Los Angeles Clippers       SF  6/29/91  32742000.0
# Paul George    Los Angeles Clippers       SF   5/2/90  33005556.0

# %%
(
    nba
    .sort_index()
    .loc["Otto Porter":"Patrick Beverley"]
)
# Out:
#                                   Team Position  Birthday      Salary
# Name
# Otto Porter              Chicago Bulls       SF    6/3/93  27250576.0
# PJ Dozier               Denver Nuggets       PG  10/25/96     79568.0
# PJ Washington        Charlotte Hornets       PF   8/23/98   3831840.0
# Pascal Siakam          Toronto Raptors       PF    4/2/94   2351838.0
# Pat Connaughton        Milwaukee Bucks       SG    1/6/93   1723050.0
# Patrick Beverley  Los Angeles Clippers       PG   7/12/88  12345680.0

# %%
nba.sort_index()
# Out:
#                                     Team Position  Birthday      Salary
# Name
# Aaron Gordon               Orlando Magic       PF   9/16/95  19863636.0
# Aaron Holiday             Indiana Pacers       PG   9/30/96   2239200.0
# Abdel Nader        Oklahoma City Thunder       SF   9/25/93   1618520.0
# Adam Mokoka                Chicago Bulls        G   7/18/98     79568.0
# Admiral Schofield     Washington Wizards       SF   3/30/97   1000000.0
# ...                                  ...      ...       ...         ...
# Zach LaVine                Chicago Bulls       PG   3/10/95  19500000.0
# Zach Norvell          Los Angeles Lakers       SG   12/9/97     79568.0
# Zhaire Smith          Philadelphia 76ers       SG    6/4/99   3058800.0
# Zion Williamson     New Orleans Pelicans        F    7/6/00   9757440.0
# Zylan Cheatham      New Orleans Pelicans       SF  11/17/95     79568.0
#
# [450 rows x 4 columns]

# %%
(
    nba
    .sort_index()
    .loc["Zach Collins":]
)
# Out:
#                                    Team Position  Birthday      Salary
# Name
# Zach Collins     Portland Trail Blazers        C  11/19/97   4240200.0
# Zach LaVine               Chicago Bulls       PG   3/10/95  19500000.0
# Zach Norvell         Los Angeles Lakers       SG   12/9/97     79568.0
# Zhaire Smith         Philadelphia 76ers       SG    6/4/99   3058800.0
# Zion Williamson    New Orleans Pelicans        F    7/6/00   9757440.0
# Zylan Cheatham     New Orleans Pelicans       SF  11/17/95     79568.0

# %%
(
    nba
    .sort_index()
    .loc[:"Al Horford"]
)
# Out:
#                                     Team Position Birthday      Salary
# Name
# Aaron Gordon               Orlando Magic       PF  9/16/95  19863636.0
# Aaron Holiday             Indiana Pacers       PG  9/30/96   2239200.0
# Abdel Nader        Oklahoma City Thunder       SF  9/25/93   1618520.0
# Adam Mokoka                Chicago Bulls        G  7/18/98     79568.0
# Admiral Schofield     Washington Wizards       SF  3/30/97   1000000.0
# Al Horford            Philadelphia 76ers        C   6/3/86  28000000.0

# %%
nba.iloc[ 300 ]
# Out:
# Team        Denver Nuggets
# Position                PF
# Birthday            4/3/99
# Salary           1416852.0
# Name: Jarred Vanderbilt, dtype: object

# %%
nba.iloc[ [100, 200, 300, 400] ]
# Out:
#                                 Team Position Birthday     Salary
# Name
# Brian Bowen           Indiana Pacers       SG  10/2/98    79568.0
# Marco Belinelli    San Antonio Spurs       SF  3/25/86  5846154.0
# Jarred Vanderbilt     Denver Nuggets       PF   4/3/99  1416852.0
# Louis King           Detroit Pistons        F   4/6/99    79568.0

# %%
nba.iloc[400:404]
nba.iloc[:2]
nba.iloc[447:]
nba.iloc[-10:-6]
nba.iloc[0:10:2] # every other rows
# Out:
#                              Team Position Birthday      Salary
# Name
# Shake Milton   Philadelphia 76ers       SG  9/26/96   1445697.0
# PJ Washington   Charlotte Hornets       PF  8/23/98   3831840.0
# Marial Shayok  Philadelphia 76ers        G  7/26/95         NaN
# Kendrick Nunn          Miami Heat       SG   8/3/95   1416852.0
# Brook Lopez       Milwaukee Bucks        C   4/1/88  12093024.0

# %%
import pandas as pd
nfl = pd.read_csv("https://bcdanl.github.io/data/nfl.csv")

# %%
nfl.nlargest(5, "Salary")
# Out:
#                  Name                  Team Position    Birthday    Salary
# 180      Kirk Cousins     Minnesota Vikings       QB   8/19/1988  27500000
# 905    Marcus Mariota      Tennessee Titans       QB  10/30/1993  20922000
# 1623   Jameis Winston  Tampa Bay Buccaneers       QB    1/6/1994  20922000
# 1343       Derek Carr       Oakland Raiders       QB   3/28/1991  19900000
# 150   Jimmy Garoppolo   San Francisco 49Ers       QB   11/2/1991  17200000

# %%
nfl.sort_values("Birthday")
# Out:
#                    Name                  Team Position  Birthday    Salary
# 421   Jason Pierre-Paul  Tampa Bay Buccaneers      OLB  1/1/1989  13650000
# 705    Trumaine Johnson         New York Jets       CB  1/1/1990   8000000
# 589         Darius Slay         Detroit Lions       CB  1/1/1991  12550000
# 1108   Xavier Su'a-Filo        Dallas Cowboys        G  1/1/1991    805000
# 488    Travis Frederick        Dallas Cowboys        C  1/1/1991   6000000
# ...                 ...                   ...      ...       ...       ...
# 1339     Andrew Sendejo     Minnesota Vikings       SS  9/9/1987    930000
# 738           Eric Kush      Cleveland Browns        G  9/9/1989   1100000
# 1494      Casey Hayward  Los Angeles Chargers       CB  9/9/1989   8000000
# 1077        Rick Lovato   Philadelphia Eagles       LS  9/9/1992    720000
# 37         Frank Herron         Detroit Lions       DE  9/9/1994    495000
#
# [1655 rows x 5 columns]

# %%
nfl.set_index("Name, inplace")

# %%
Q7:

q7 = (
    nfl
    . reset_index()
    .set_index("Team")
)

# %%
nba.loc[
    "LeBron James",
    "Team"
]

nba.loc[
     "James Harden",
      ["Position", "Birthday"]
]
# Out:
# Position         PG
# Birthday    8/26/89
# Name: James Harden, dtype: object

# %%
nba.loc[
    ["Russell Westbrook", "Anthony Davis"],
     ["Team", "Salary"]
]

nba.loc[
    "Joel Embiid",
    "Position":"Salary"
]
# Out:
# Position             C
# Birthday       3/16/94
# Salary      27504630.0
# Name: Joel Embiid, dtype: object

# %%
nba.max()
# Out:
# Team        Washington Wizards
# Position                    SG
# Birthday                9/9/93
# Salary              40231758.0
# dtype: object

# %%
nba = pd.read_csv("")

# %%
nba.min()
# Out:
# Team        Atlanta Hawks
# Position                C
# Birthday          1/10/98
# Salary            79568.0
# dtype: object

# %%
nba.sum()
nba.mean()
nba.median()
nba.quantile(0.75) # 0 to 1
nba.std()
# Out:
# <ipython-input-34-356dc32fd7d3>:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   nba.mean()
# <ipython-input-34-356dc32fd7d3>:3: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   nba.median()
# <ipython-input-34-356dc32fd7d3>:4: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   nba.quantile(0.75) # 0 to 1
# <ipython-input-34-356dc32fd7d3>:5: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   nba.std()
# Salary    9.292269e+06
# dtype: float64

# %%
nba.sum(numeric_only = True)
nba.mean(numeric_only = True)
nba.median(numeric_only = True)
nba.quantile(0.75, numeric_only=True)
nba.std(numeric_only = True)
# Out:
# Salary    9.292269e+06
# dtype: float64

# %%
nba["Salary_2x"] = nba["Salary"] + nba["Salary"]
nba["Name_w_Position"] = nba["Name"] + " (" + nba["Position"] + ")"
nba["Salary_minus_Mean"] = nba["Salary"] - nba["Salary"].mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-ba75af30e59e> in <cell line: 2>()
#       1 nba["Salary_2x"] = nba["Salary"] + nba["Salary"]
# ----> 2 nba["Name_w_Position"] = nba["Name"] + " (" + nba["Position"] + ")"
#       3 nba["Salary_minus_Mean"] = nba["Salary"] - nba["Salary"].mean()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3805             if self.columns.nlevels > 1:
#    3806                 return self._getitem_multilevel(key)
# -> 3807             indexer = self.columns.get_loc(key)
#    3808             if is_integer(indexer):
#    3809                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
# -> 3804                 raise KeyError(key) from err
#    3805             except TypeError:
#    3806                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Name'

# %%
nba.columns = ["Team", "Position", "Date of Birth", "Income"]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-266ac580ab92> in <cell line: 1>()
# ----> 1 nba.columns = ["Team", "Position", "Date of Birth", "Income"]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5913         try:
#    5914             object.__getattribute__(self, name)
# -> 5915             return object.__setattr__(self, name, value)
#    5916         except AttributeError:
#    5917             pass
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
#     821     def _set_axis(self, axis: int, labels: AnyArrayLike | list) -> None:
#     822         labels = ensure_index(labels)
# --> 823         self._mgr.set_axis(axis, labels)
#     824         self._clear_item_cache()
#     825
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in set_axis(self, axis, new_labels)
#     228     def set_axis(self, axis: int, new_labels: Index) -> None:
#     229         # Caller is responsible for ensuring we have an Index object.
# --> 230         self._validate_set_axis(axis, new_labels)
#     231         self.axes[axis] = new_labels
#     232
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/base.py in _validate_set_axis(self, axis, new_labels)
#      68
#      69         elif new_len != old_len:
# ---> 70             raise ValueError(
#      71                 f"Length mismatch: Expected axis has {old_len} elements, new "
#      72                 f"values have {new_len} elements"
#
# ValueError: Length mismatch: Expected axis has 5 elements, new values have 4 elements

# %%
nba.rename( columns = { "Date of Birth": "Birthday" } )
# Out:
#                                Team Position  Birthday      Salary   Salary_2x
# Name
# Shake Milton     Philadelphia 76ers       SG   9/26/96   1445697.0   2891394.0
# Christian Wood      Detroit Pistons       PF   9/27/95   1645357.0   3290714.0
# PJ Washington     Charlotte Hornets       PF   8/23/98   3831840.0   7663680.0
# Derrick Rose        Detroit Pistons       PG   10/4/88   7317074.0  14634148.0
# Marial Shayok    Philadelphia 76ers        G   7/26/95         NaN         NaN
# ...                             ...      ...       ...         ...         ...
# Austin Rivers       Houston Rockets       PG    8/1/92   2174310.0   4348620.0
# Harry Giles        Sacramento Kings       PF   4/22/98   2578800.0   5157600.0
# Robin Lopez         Milwaukee Bucks        C    4/1/88   4767000.0   9534000.0
# Collin Sexton   Cleveland Cavaliers       PG    1/4/99   4764960.0   9529920.0
# Ricky Rubio            Phoenix Suns       PG  10/21/90  16200000.0  32400000.0
#
# [450 rows x 5 columns]

# %%
nba
# Out:
#                                Team Position  Birthday      Salary   Salary_2x
# Name
# Shake Milton     Philadelphia 76ers       SG   9/26/96   1445697.0   2891394.0
# Christian Wood      Detroit Pistons       PF   9/27/95   1645357.0   3290714.0
# PJ Washington     Charlotte Hornets       PF   8/23/98   3831840.0   7663680.0
# Derrick Rose        Detroit Pistons       PG   10/4/88   7317074.0  14634148.0
# Marial Shayok    Philadelphia 76ers        G   7/26/95         NaN         NaN
# ...                             ...      ...       ...         ...         ...
# Austin Rivers       Houston Rockets       PG    8/1/92   2174310.0   4348620.0
# Harry Giles        Sacramento Kings       PF   4/22/98   2578800.0   5157600.0
# Robin Lopez         Milwaukee Bucks        C    4/1/88   4767000.0   9534000.0
# Collin Sexton   Cleveland Cavaliers       PG    1/4/99   4764960.0   9529920.0
# Ricky Rubio            Phoenix Suns       PG  10/21/90  16200000.0  32400000.0
#
# [450 rows x 5 columns]

# %%
ref_var = nba.columns.get_loc('Team')
var_to_move = nba.pop('Salary')
nba.insert(ref_var, 'Salary', var_to_move) # insert() directly alters 'nba'

# %%
import pandas as pd
# Below is for an interactive display of DataFrame in Colab
from google.colab import data_table
data_table.enable_dataframe_formatter()

emp = pd.read_csv("https://bcdanl.github.io/data/employment.csv")

# %%
emp["Mgmt"].astype(bool)
# Out:
# 0        True
# 1        True
# 2       False
# 3        True
# 4        True
#         ...
# 996     False
# 997     False
# 998     False
# 999      True
# 1000     True
# Name: Mgmt, Length: 1001, dtype: bool

# %%
emp["Mgmt"] = emp["Mgmt"].astype(bool)

# %%
emp["Salary"].astype(int)
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# <ipython-input-45-09e98607130a> in <cell line: 1>()
# ----> 1 emp["Salary"].astype(int)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6238         else:
#    6239             # else, only a single dtype is given
# -> 6240             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241             return self._constructor(new_data).__finalize__(self, method="astype")
#    6242
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     446
#     447     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 448         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     449
#     450     def convert(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     350                     applied = b.apply(f, **kwargs)
#     351                 else:
# --> 352                     applied = getattr(b, f)(**kwargs)
#     353             except (TypeError, NotImplementedError):
#     354                 if not ignore_failures:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors)
#     524         values = self.values
#     525
# --> 526         new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     527
#     528         new_values = maybe_coerce_values(new_values)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/dtypes/astype.py in astype_array_safe(values, dtype, copy, errors)
#     297
#     298     try:
# --> 299         new_values = astype_array(values, dtype, copy=copy)
#     300     except (ValueError, TypeError):
#     301         # e.g. astype_nansafe can fail on object-dtype of strings
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/dtypes/astype.py in astype_array(values, dtype, copy)
#     228
#     229     else:
# --> 230         values = astype_nansafe(values, dtype, copy=copy)
#     231
#     232     # in pandas we don't store numpy str dtypes, so convert to object
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/dtypes/astype.py in astype_nansafe(arr, dtype, copy, skipna)
#     138
#     139     elif np.issubdtype(arr.dtype, np.floating) and is_integer_dtype(dtype):
# --> 140         return _astype_float_to_int_nansafe(arr, dtype, copy)
#     141
#     142     elif is_object_dtype(arr.dtype):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/dtypes/astype.py in _astype_float_to_int_nansafe(values, dtype, copy)
#     180     """
#     181     if not np.isfinite(values).all():
# --> 182         raise IntCastingNaNError(
#     183             "Cannot convert non-finite values (NA or inf) to integer"
#     184         )
#
# IntCastingNaNError: Cannot convert non-finite values (NA or inf) to integer
